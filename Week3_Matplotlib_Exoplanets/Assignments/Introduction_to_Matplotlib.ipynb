# %% [markdown]
# # Introduction to Matplotlib
#
# Joshua Liberman, Intro2Astro2024
#
# Modified from Kazi Abu Rousan, Intro2Astro2023

# %% [markdown]
# Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. Matplotlib makes easy things easy and hard things possible.
#
# - Create publication quality plots.
# - Make interactive figures that can zoom, pan, update.
# - Customize visual style and layout.
# - Export to many file formats.
# - Embed in JupyterLab and Graphical User Interfaces.
# - Use a rich array of third-party packages built on Matplotlib.

# %% [markdown]
# It has many powerful submodule but we are only going to see 2 of them.

# %%
import matplotlib.pyplot as plt #import a submodule named pyplot
#this is used for basic plots
import numpy as np #again numpy see told you this is one of the most important

# %% [markdown]
# For scientific plotting, this library can serve as a useful resource: https://github.com/garrettj403/SciencePlots
#
# pip install SciencePlots

# %% [markdown]
# From SciencePlots, we're going to use some style files. These files contain formatting parameters that will be applied to all of your plots.

# %% [markdown]
# To further customize your plots, you can try creating your own style file: https://loganpearce.wordpress.com/2024/06/05/custom-matplotlib-style-files/

# %%
#pip install scienceplots

# %%
# import scienceplots and use the 'science', 'notebook', and 'grid' style files
import scienceplots
plt.style.use(['science', 'notebook', 'grid']) # run after installing Scientific Plots package

# %% [markdown]
# ## Basic 1D Plots

# %% [markdown]
# ### Line Plots

# %% [markdown]
# Suppose we want to plot the function $y = x^2$. To do that, we need data points, i.e, coordinate points. These are made using numpy.

# %%
x_values = np.linspace(0,10,5)
x_values# see as discussed in the previous lecture, it creates 5 numbers between 0 to 10
# Out:
# array([ 0. ,  2.5,  5. ,  7.5, 10. ])

# %%
y_values = x_values**2
print(y_values)
# Out:
# [  0.     6.25  25.    56.25 100.  ]

# %%
plt.plot(x_values,y_values)
plt.show()#to show the plot. In jupyter notebook we don't need this actually but it's a good practice

# %% [markdown]
# See because there are only 5 points and they are connected by lines, They don't look too good.
#
# **So, Let's increase the number of points**

# %%
x_values = np.linspace(0,10,100)
y_values = x_values**2
plt.plot(x_values,y_values)
plt.show()## Smooth curve...

# %% [markdown]
# To change the plotting style, use the syntax

# %%
plt.plot(x_values,y_values, color="Red", ls="--")#ls means line-style
plt.show()## Smooth curve...

# %% [markdown]
# supported values are **'-'**, **'--'**, **'-.'**, **':'**, **'None'**, **' '**, **''**, **'solid'**, **'dashed'**, **'dashdot'**, **'dotted'**

# %% [markdown]
# If you want to see the points along with line use,

# %%
x = np.linspace(-2,2,10)
y = x**2
plt.plot(x,y, 'o--', color='red', lw=2, ms=10) #lw is line width, ms is marker size

# %% [markdown]
# Equivalently, you can use the syntax

# %%
plt.plot(x,y, linestyle='--', marker='o', color='red', linewidth=2, markersize=10)

# %% [markdown]
# The above syntax can be useful as a way of self-documenting your code. As you continue to progress as a programmer and a researcher, you will learn that documenting code is very important.

# %% [markdown]
# To change the figure size

# %%
plt.figure(figsize=(8,3))
plt.plot(x,y)

# %% [markdown]
# When we have more than one plot, we need to label things. We can also add title and axis label.

# %%
x = np.linspace(-2,2,100)
y = 4*np.sin(x)
y1 = 4*np.cos(x)

# %%
plt.figure(figsize=(8,3))
plt.plot(x,y1,ls="--", label=r'$\sin(x)$') # The $\sin(x)$ is Latex syntax. You will learn more about this later in the course.
plt.plot(x,y, label=r'$\cos(x)$')
plt.xlabel('x-axis', fontsize=16)
plt.ylabel('y-axis', fontsize=16)
plt.title('Plots of Different Functions')
plt.legend(loc='lower right', fontsize=12, ncol=1)#ncol tells you how many columns will be there
plt.show()

# %% [markdown]
# The position of the label have many options.
#
# Here they are:
#
# 'best', 'upper right', 'upper left', 'lower left', 'lower right', 'right', 'center left', 'center right', 'lower center', 'upper center', 'center'

# %%
y2 = np.cos(x**2)
y3 = np.sin(x*6)
plt.figure(figsize=(8,3))
plt.plot(x,y1,ls="--", label=r'$\sin(x)$')
plt.plot(x,y, label=r'$\cos(x)$', ls="-.") # By calling plt.plot() in sequence, we can plot multiple functions on top of each other
plt.plot(x,y2, label=r'$\cos(x^2)$',ls=":")
plt.plot(x,y3, label=r'$\cos(6x)$')
plt.xlabel('x-axis', fontsize=16)
plt.ylabel('y-axis')
plt.title('Plots of Different Functions')
plt.legend(loc='lower right', fontsize=12, ncol=2) # ncol tells you the how many columns will be there
plt.show()

# %% [markdown]
# To save an image use `savefig`

# %%
plt.figure(figsize=(8,3))
plt.plot(x,y1,ls="--", label=r'$\sin(x)$')
plt.plot(x,y, label=r'$\cos(x)$', ls="-.")
plt.plot(x,y2, label=r'$\cos(x^2)$',ls=":")
plt.plot(x,y3, label=r'$\cos(6x)$')
plt.xlabel('x-axis', fontsize=16)
plt.ylabel('y-axis')
plt.title('Plots of Different Functions')
plt.legend(loc='lower right', fontsize=12, ncol=2)#ncol tells you the how many columns will be there
plt.savefig("plot.pdf")# this save the plot in the folder where you are running your notebook
plt.show()
#with the name plot in pdf format.

# %% [markdown]
# ### Scatter Plots

# %% [markdown]
# Scatter Plot means we are only plotting data points.

# %%
x = np.linspace(0,15,30)
y = np.sin(x) + 0.1*np.random.randn(len(x))
x1 = np.linspace(0, 15, 100)
y1 = np.sin(x1)

plt.figure(figsize=(8,3))
plt.scatter(x,y,label='Data')
plt.xlabel('Time [s]', fontsize=16)
plt.ylabel('Voltage [V]')
plt.title('Voltage in 3rd Electrode')
plt.legend(loc='upper right', fontsize=12, ncol=2)
plt.ylim(top=2)
plt.show()

# %% [markdown]
# ### Plot Histogram

# %%
res = np.random.randn(1000)*0.2 + 0.4 # Generate a sample of 1000 values from a normal distribution with a mean of 0.4
                                      # and a standard deviation of 0.2

# %% [markdown]
# For Histogram use `hist`

# %% [markdown]
# We can change the bin number.

# %%
plt.figure(figsize=(8,3))
plt.hist(res, bins=30)
plt.show()

# %%
plt.figure(figsize=(8,3))
plt.hist(res)
plt.show()

# %% [markdown]
# We can also choose to only draw the boundary

# %%
plt.figure(figsize=(8,3))
plt.hist(res, bins=30, density=True, histtype='step')
plt.xlabel('$\hat{E}-E$', fontsize=20)
plt.ylabel('Frequency')
plt.show()
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\h'
# <>:3: SyntaxWarning: invalid escape sequence '\h'
# /tmp/ipykernel_16212/3494589007.py:3: SyntaxWarning: invalid escape sequence '\h'
#   plt.xlabel('$\hat{E}-E$', fontsize=20)

# %% [markdown]
# ## SubFigures

# %%
# This plotting method allows you to create multiple diagrams in the same window. 
fig, axes = plt.subplots(1, 2, figsize=(16,8))#1*2= 2 subplots will be created
#-----------------------------------------------------------------------------
ax = axes[0]
ax.plot(x, y, 'o--', color='r', lw=0.4, ms=3)
ax.set_xlabel('x-axis for 1st plot')
#-----------------------------------------------------------------------------
ax = axes[1]
ax.hist(res, bins=30, density=True, histtype='step', label='C1')
#-----------------------------------------------------------------------------
fig.tight_layout()#reduce the white region from boundary
fig.suptitle('Title of All Plots', y=1.03, fontsize=25)
plt.show()

# %% [markdown]
# ### Error bars

# %% [markdown]
# Sometimes in data we have some error. So, to correctly specify the value we add the error bars.

# %%
fig = plt.figure()
x = np.arange(10)
y = 2.5 * np.sin(x / 20 * np.pi)
yerr = np.linspace(0.05, 0.2, 10)

plt.errorbar(x, y + 3, yerr=yerr, label='both limits (default)')

plt.errorbar(x, y + 2, yerr=yerr, uplims=True, label='uplims=True')

plt.errorbar(x, y + 1, yerr=yerr, uplims=True, lolims=True,
             label='uplims=True, lolims=True')

upperlimits = [True, False] * 5
lowerlimits = [False, True] * 5
plt.errorbar(x, y, yerr=yerr, uplims=upperlimits, lolims=lowerlimits,
             label='subsets of uplims and lolims')

plt.legend(loc='lower right',fontsize=12)
plt.show()

# %% [markdown]
# ## Application in Astronomy

# %% [markdown]
# Matplotlib is often used in astronomy for data visualization.

# %% [markdown]
# Let's see a few examples

# %%
from astropy.io import fits
from astropy.wcs import WCS

# %%
hdul = fits.open('s0002.fits')
data = hdul[0].data
h1 = hdul[0].header
obj_name = h1.get('OBJECT', 'Unknown')

flux = data[0]
w = WCS(h1, naxis=1, relax=False, fix=False)
wvl = w.wcs_pix2world(np.arange(len(flux)), 0)[0]

plt.plot(wvl, flux)

plt.axvline(x=5895.6, color='red', linestyle='--', label='Na Absorption')
plt.axvline(x=4364.436, color='black', linestyle='--', label=r'$O_{III}$ Emissive')
plt.legend()
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Normalized flux')
plt.show()

# %% [markdown]
# This at once give us so much information. We can see the dips, they are absorption lines. See, just by looking into the data we cannot say much. But now just by looking into this we can say so much about it.

# %% [markdown]
# This is not all, we can do more. We can plot H-R diagrams and visualize the data.

# %%
#pip install astroquery

# %%
from astroquery.gaia import Gaia
from astropy.table import Table

# %%
tables = Gaia.load_tables(only_names = True)
for table in tables:
    if 'gaiadr3' in table.get_qualified_name():
        print(table.get_qualified_name())
# Out:
# INFO: Retrieving tables... [astroquery.utils.tap.core]
# INFO: Parsing tables... [astroquery.utils.tap.core]
# INFO: Done. [astroquery.utils.tap.core]
# gaiadr3.gaiadr3.gaia_source
# gaiadr3.gaiadr3.gaia_source_lite
# gaiadr3.gaiadr3.astrophysical_parameters
# gaiadr3.gaiadr3.astrophysical_parameters_supp
# gaiadr3.gaiadr3.oa_neuron_information
# gaiadr3.gaiadr3.oa_neuron_xp_spectra
# gaiadr3.gaiadr3.total_galactic_extinction_map
# gaiadr3.gaiadr3.total_galactic_extinction_map_opt
# gaiadr3.gaiadr3.commanded_scan_law
# gaiadr3.gaiadr3.allwise_best_neighbour
# gaiadr3.gaiadr3.allwise_neighbourhood
# gaiadr3.gaiadr3.apassdr9_best_neighbour
# gaiadr3.gaiadr3.apassdr9_join
# gaiadr3.gaiadr3.apassdr9_neighbourhood
# gaiadr3.gaiadr3.dr2_neighbourhood
# gaiadr3.gaiadr3.gsc23_best_neighbour
# gaiadr3.gaiadr3.gsc23_join
# gaiadr3.gaiadr3.gsc23_neighbourhood
# gaiadr3.gaiadr3.hipparcos2_best_neighbour
# gaiadr3.gaiadr3.hipparcos2_neighbourhood
# gaiadr3.gaiadr3.panstarrs1_best_neighbour
# ...

# %%
query = """SELECT source_id, ra, dec, parallax, phot_g_mean_mag, phot_bp_mean_mag, phot_rp_mean_mag FROM gaiadr3.gaia_source WHERE parallax > 50"""
job = Gaia.launch_job_async(query)
gtable = job.get_results()
# Out:
# INFO: Query finished. [astroquery.utils.tap.core]

# %%
print(gtable.info)
# Out:
# <Table length=2626>
#       name        dtype  unit                            description                             n_bad
# ---------------- ------- ---- ------------------------------------------------------------------ -----
#        SOURCE_ID   int64      Unique source identifier (unique within a particular Data Release)     0
#               ra float64  deg                                                    Right ascension     0
#              dec float64  deg                                                        Declination     0
#         parallax float64  mas                                                           Parallax     0
#  phot_g_mean_mag float32  mag                                              G-band mean magnitude     6
# phot_bp_mean_mag float32  mag                                       Integrated BP mean magnitude    60
# phot_rp_mean_mag float32  mag                                       Integrated RP mean magnitude    54

# %%
bp_rp = gtable['phot_bp_mean_mag'] - gtable['phot_rp_mean_mag']
fig, ax = plt.subplots(1,1,figsize=(7,7))
ax.hexbin(bp_rp, gtable['phot_g_mean_mag'],bins='log', mincnt=1)
ax.set_xlabel(r"$G_{BP} - G_{RP}$")
ax.set_ylabel(r"G")
ax.set_title("Hertzsprung Russell Diagram Before Filtering from Gaia3")
ax.invert_yaxis()
plt.show()

# %%
abs_gmag = 5*np.log10(gtable['parallax']) - 10 + gtable['phot_g_mean_mag']
fig, ax = plt.subplots(1,1,figsize=(7,7))
ax.hexbin(bp_rp, abs_gmag,bins='log', mincnt=1)
ax.set_xlabel(r"$G_{BP} - G_{RP}$")
ax.set_ylabel(r"G")
ax.set_title("Hertzsprung Russell Diagram After Filtering from Gaia3")
ax.invert_yaxis()
plt.show()

# %% [markdown]
# We can also use fits file to make coloured mapped plots.

# %%
h = fits.open('example_data.fits')
data = h[0].data
plt.imshow(np.log(data), origin='lower') # the origin='lower' argument ensures that the y-axis starts at 0
plt.show()
# Out:
# /tmp/ipykernel_16212/3120348531.py:3: RuntimeWarning: invalid value encountered in log
#   plt.imshow(np.log(data), origin='lower') # the origin='lower' argument ensures that the y-axis starts at 0

# %%
from astropy.visualization import astropy_mpl_style
plt.style.use(astropy_mpl_style)
from astropy.utils.data import get_pkg_data_filename
image_file = get_pkg_data_filename('tutorials/FITS-images/HorseHead.fits')

# %%
image_data = fits.getdata(image_file, ext=0)
plt.figure()
plt.imshow(image_data, cmap='gray', origin='lower') 
plt.colorbar()
plt.show()

# %% [markdown]
# You make a plot

# %% [markdown]
# Below are some fake data for you to plot.Try making a plot that has three axes on top of each other

# %% [markdown]
# (Top plot): A scatterplot of the data. Add in errorbars for the y-values.

# %% [markdown]
# (Middle plot): Draw a straight line through the data, tweaking the values for the line until it looks like it goes through
# all the points equally well. Make a legend specifying the line from the data.

# %% [markdown]
# (Bottom plot): A histogram of the x and y data on a single plot.

# %%
x = np.array([7.1,9.4,9.1,3.6,2.6,4.1,3.8,6.4,8.8,9.8,
              6.0,9.8,8.5,0.6,5.9,7.5,0.9,5.5,4.6,9.])
y = np.array([21.0,25.3,24.8,10.0,9.2,9.0,11.3,17.0,24.0,27.1,
              18.0,25.8,23.2,4.0,17.2,19.1,2.9,13.6,11.4,25.])
yerr = 1

# %%
# Create figure and axes objects
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(8, 8))

# Subplot 1: Scatterplot with errorbars
ax1.scatter(x, y, color='blue')
ax1.errorbar(x, y, yerr=yerr, fmt='none', ecolor='red')
ax1.set_title('Scatterplot with Errorbars')
ax1.set_xlabel('X')
ax1.set_ylabel('Y')

# Subplot 2: Straight line through the data
slope, intercept = np.polyfit(x, y, 1)
line_x = np.linspace(min(x), max(x), 100)
line_y = slope * line_x + intercept
ax2.plot(line_x, line_y, color='orange', label=f'Slope: {slope:.2f}, Intercept: {intercept:.2f}')
ax2.scatter(x, y, color='blue')
ax2.set_title('Straight Line through Data')
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.legend()

# Subplot 3: Histogram of x and y data
ax3.hist(x, bins=10, alpha=0.5, label='X')
ax3.hist(y, bins=10, alpha=0.5, label='Y')
ax3.set_title('Histogram of X and Y')
ax3.set_xlabel('Value')
ax3.set_ylabel('Count')
ax3.legend()

# Adjust the spacing between subplots
fig.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# # Extended Exercises

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# Use Numpy to generate 10000 random values following a Gaussian/Normal distribution, and make a histogram. Try changing    the number of bins to properly see the Gaussian. Try overplotting a Gaussian function on top of it using a colored line, and adjust the normalization so that the histogram and the line are aligned

# %%
# your solution here

# Generate 10,000 random values following a Gaussian/Normal distribution
mean = 0
std_dev = 1
num_samples = 10000
data = np.random.normal(mean, std_dev, num_samples)

# Create a histogram of the data
fig, ax = plt.subplots(figsize=(8, 6))
num_bins = 50
ax.hist(data, num_bins, density=True, color='lightblue', edgecolor='black')

# Overlay a Gaussian function on the histogram
x = np.linspace(min(data), max(data), 100)
gaussian = (1 / (std_dev * np.sqrt(2 * np.pi))) * np.exp(-((x - mean) ** 2) / (2 * std_dev ** 2))
ax.plot(x, gaussian, color='red', linewidth=2)

# Adjust the plot
ax.set_title('Histogram of Gaussian/Normal Distribution')
ax.set_xlabel('Value')
ax.set_ylabel('Density')
ax.grid(True)

plt.show()

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# The [central limit theorem](http://en.wikipedia.org/wiki/Central_limit_theorem) states that the arithmetic mean of a large
# number of independent random samples (from any distribution) will approach a normal distribution. You can easily test this
# with Numpy and Matplotlib:
#
# 1. Create an empty array ``total`` with 10000 values (set to 0)
# 2. Generate 10000 random values uniformly between 0 and 1
# 3. Add these values to the ``total`` array
# 4. Repeat steps 2 and 3 10 times
# 5. Divide ``total`` by 10 to get the mean of the values you added
# 5. Make a histogram of the values in ``total``
#
# You can also see how the histogram of ``total`` values changes at each step, if you want to see the evolution!

# %%
# 1
total = np.zeros(10000)

# 2-4
for _ in range(10):
    total += np.random.uniform(0, 1, 10000)

# 5
total /= 10

# 6
plt.figure(figsize=(8, 6))
plt.hist(total, bins=50, density=True, alpha=0.7)
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Histogram of the Sample Mean')
plt.show()

# %% [markdown]
# For more information, explore these resources:
#  - https://matplotlib.org/stable/gallery/index.html (Examples of various plots that you can create)
#  - https://matplotlib.org/Matplotlib.pdf
#  - https://link.springer.com/book/10.1007/978-1-4842-7410-1
#  - https://github.com/rougier/scientific-visualization-book (Highly recommended, The best of the best)

# %% [markdown]
# The above resources contain a lot of information, and it can appear overwhelming. In research, it is often useful to draw from various resources on an as-needed basis.
